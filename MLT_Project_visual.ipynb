# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv("Fertilizer_dataset.csv")
print("Dataset Head")
print(data.head())
# Out:
# Dataset Head
#    Nitrogen  Phosphorus  Potassium  Soil_pH  Rainfall  Sunlight  Yield
# 0    106.18       24.13      36.89     5.92    239.57      7.11   7.31
# 1    192.61       62.51      47.86     5.55     56.15      6.88  13.28
# 2    159.80       63.25      37.70     5.86     55.53      4.15  15.16
# 3    139.80       70.99      28.87     6.67    130.90      6.05  11.25
# 4     73.40       78.09      32.06     6.34    172.16      6.28   7.78

# %%
print("\n===== Dataset Info =====")
print(data.info())
# Out:
# ===== Dataset Info =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Nitrogen    300 non-null    float64
#  1   Phosphorus  300 non-null    float64
#  2   Potassium   300 non-null    float64
#  3   Soil_pH     300 non-null    float64
#  4   Rainfall    300 non-null    float64
#  5   Sunlight    300 non-null    float64
#  6   Yield       300 non-null    float64
# dtypes: float64(7)
# memory usage: 16.5 KB
# None

# %%
print("\n===== Dataset Description =====")
print(data.describe())
# Out:
# ===== Dataset Description =====
#          Nitrogen  Phosphorus   Potassium     Soil_pH    Rainfall    Sunlight  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean   124.280500   60.866567   67.108900    6.538867  175.040767    6.930767
# std     44.151022   24.207085   28.342891    0.594017   73.059366    1.738539
# min     50.760000   20.870000   20.460000    5.510000   51.230000    4.050000
# 25%     85.860000   39.970000   40.975000    6.020000  109.295000    5.397500
# 50%    126.755000   61.735000   65.285000    6.590000  173.680000    6.955000
# 75%    163.527500   81.870000   91.700000    7.072500  233.485000    8.357500
# max    198.510000   99.980000  119.690000    7.500000  299.850000    9.980000
#
#             Yield
# count  300.000000
# mean    13.138000
# std      3.253719
# min      4.070000
# 25%     10.980000
# 50%     13.140000
# 75%     15.477500
# max     20.650000

# %%
print("\n===== Missing Values =====")
print(data.isnull().sum())
data.fillna(data.mean(), inplace=True)
# Out:
# ===== Missing Values =====
# Nitrogen      0
# Phosphorus    0
# Potassium     0
# Soil_pH       0
# Rainfall      0
# Sunlight      0
# Yield         0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Yield'], bins=15, kde=True, color="green")
plt.title("Yield Distribution")
plt.xlabel("Yield (tons/ha)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(12,6))
data[['Nitrogen','Phosphorus','Potassium','Yield']].boxplot()
plt.title("Boxplot of Fertilizers and Yield")
plt.ylabel("Value")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=importances, y=feat_names, palette="viridis")
plt.title("Feature Importance (Random Forest)")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()
# Out:
# C:\Users\atlal\AppData\Local\Temp\ipykernel_33492\2012396637.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importances, y=feat_names, palette="viridis")
